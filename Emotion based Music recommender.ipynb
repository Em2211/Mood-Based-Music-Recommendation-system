# %%
import cv2
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import imutils
from keras.utils import img_to_array
from keras.models import load_model

import lightgbm
from lightgbm import LGBMClassifier

import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Spotify Dataset Analysis\data.csv.zip',compression='zip')
data
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714             ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                        ['Ingrid Andress']         0.512
#
#         duration_ms  energy  explicit                      id  \
# 0            158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1            282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2            104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3            180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4            687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
# ...             ...     ...       ...                     ...
# 169904       163800  0.4430         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700  0.5390         0  52eycxprLhK3lPcRLbQiVk
# 169907       167308  0.7610         0  3wYOGJYD31sLRmBgCvWxa4
# 169908       214787  0.4280         0  60RFlt48hm0l4Fu0JoccOl
#
#         instrumentalness  key  liveness  loudness  mode  \
# 0               0.563000   10    0.1510   -12.428     1
# 1               0.901000    8    0.0763   -28.454     1
# 2               0.000000    5    0.1190   -19.924     0
# 3               0.887000    1    0.1110   -14.734     0
# 4               0.908000   11    0.0980   -16.829     1
# ...                  ...  ...       ...       ...   ...
# 169904          0.000032    1    0.0891    -7.461     1
# 169905          0.031300    8    0.1110   -10.907     1
# 169906          0.002330    7    0.1080    -9.332     1
# 169907          0.000000    1    0.2220    -2.557     1
# 169908          0.000000    0    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year
# 0              1928       0.0506  118.469   0.7790  1928
# 1              1928       0.0462   83.972   0.0767  1928
# 2              1928       0.9290  107.177   0.8800  1928
# 3        1928-09-25       0.0926  108.003   0.7200  1928
# 4              1928       0.0424   62.149   0.0693  1928
# ...             ...          ...      ...      ...   ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020
# 169905   2020-06-08       0.0403  128.000   0.2700  2020
# 169906   2020-05-29       0.1050  123.700   0.1530  2020
# 169907   2020-02-28       0.0385  129.916   0.4720  2020
# 169908   2020-03-27       0.0271   80.588   0.3660  2020
#
# [169909 rows x 19 columns]

# %%
data.drop_duplicates(inplace=True,subset=['name'])

# %%
name=data['name']

# %%
col_features = ['danceability', 'energy', 'valence', 'loudness']
X = MinMaxScaler().fit_transform(data[col_features])
kmeans = KMeans(init="k-means++",
                n_clusters=2,
                random_state=15).fit(X)
data['kmeans'] = kmeans.labels_

# %%
data['song_name']=name

# %%
data
# Out:
#         acousticness                                   artists  danceability  \
# 0             0.9950                       ['Carl Woitschach']         0.708
# 1             0.9940  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2             0.6040                   ['Seweryn Goszczyński']         0.749
# 3             0.9950                      ['Francisco Canaro']         0.781
# 4             0.9900  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# ...              ...                                       ...           ...
# 169901        0.2640              ['Meek Mill', 'Roddy Ricch']         0.744
# 169903        0.2100                  ['LEGADO 7', 'Junior H']         0.795
# 169904        0.1730                    ['DripReport', 'Tyga']         0.875
# 169905        0.0167        ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380                     ['Kygo', 'Oh Wonder']         0.514
#
#         duration_ms  energy  explicit                      id  \
# 0            158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD
# 1            282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV
# 2            104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM
# 3            180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8
# 4            687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd
# ...             ...     ...       ...                     ...
# 169901       167845  0.7020         1  0j2CNrgtalXRGIvHMO2vzh
# 169903       218501  0.5850         0  52Cpyvd2dKb6XRn313nH87
# 169904       163800  0.4430         1  4KppkflX7I3vJQk7urOJaS
# 169905       167468  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ
# 169906       180700  0.5390         0  52eycxprLhK3lPcRLbQiVk
#
#         instrumentalness  key  liveness  ...  mode  \
# 0               0.563000   10    0.1510  ...     1
# 1               0.901000    8    0.0763  ...     1
# 2               0.000000    5    0.1190  ...     0
# 3               0.887000    1    0.1110  ...     0
# 4               0.908000   11    0.0980  ...     1
# ...                  ...  ...       ...  ...   ...
# 169901          0.000000    7    0.1200  ...     0
# 169903          0.000001    8    0.1120  ...     1
# 169904          0.000032    1    0.0891  ...     1
# 169905          0.031300    8    0.1110  ...     1
# 169906          0.002330    7    0.1080  ...     1
#
#                                                  name popularity  \
# 0                         Singende Bataillone 1. Teil          0
# 1            Fantasiestücke, Op. 111: Più tosto lento          0
# 2                      Chapter 1.18 - Zamek kaniowski          0
# 3       Bebamos Juntos - Instrumental (Remasterizado)          0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61          1
# ...                                               ...        ...
# 169901           Letter To Nipsey (feat. Roddy Ricch)         66
# 169903                                Ojos De Maniaco         68
# 169904                  Skechers (feat. Tyga) - Remix         75
# 169905                 Sweeter (feat. Terrace Martin)         64
# 169906                               How Would I Know         70
#
#         release_date speechiness    tempo  valence  year  kmeans  \
# 0               1928      0.0506  118.469   0.7790  1928       1
# 1               1928      0.0462   83.972   0.0767  1928       0
# 2               1928      0.9290  107.177   0.8800  1928       1
# 3         1928-09-25      0.0926  108.003   0.7200  1928       0
# 4               1928      0.0424   62.149   0.0693  1928       0
# ...              ...         ...      ...      ...   ...     ...
# 169901    2020-01-27      0.2880   91.885   0.3380  2020       1
# 169903    2020-02-28      0.0374   97.479   0.9340  2020       1
# 169904    2020-05-15      0.1430  100.012   0.3060  2020       0
# 169905    2020-06-08      0.0403  128.000   0.2700  2020       0
# 169906    2020-05-29      0.1050  123.700   0.1530  2020       0
#
#                                             song_name
# 0                         Singende Bataillone 1. Teil
# 1            Fantasiestücke, Op. 111: Più tosto lento
# 2                      Chapter 1.18 - Zamek kaniowski
# 3       Bebamos Juntos - Instrumental (Remasterizado)
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61
# ...                                               ...
# 169901           Letter To Nipsey (feat. Roddy Ricch)
# 169903                                Ojos De Maniaco
# 169904                  Skechers (feat. Tyga) - Remix
# 169905                 Sweeter (feat. Terrace Martin)
# 169906                               How Would I Know
#
# [132940 rows x 21 columns]

# %%
cluster=data.groupby(by=data['kmeans'])
cluster.mean()
# Out:
#         acousticness  danceability    duration_ms    energy  explicit  \
# kmeans
# 0           0.723316      0.449511  239809.866976  0.260947  0.061714
# 1           0.333270      0.602004  225183.332831  0.651267  0.110510
#
#         instrumentalness       key  liveness   loudness      mode  popularity  \
# kmeans
# 0               0.253267  5.069647  0.201737 -15.380623  0.721863   22.351796
# 1               0.103271  5.301801  0.218894  -8.625437  0.696369   36.068179
#
#         speechiness       tempo   valence         year
# kmeans
# 0          0.109725  109.543416  0.336699  1967.117844
# 1          0.096229  122.205031  0.677247  1983.579777

# %%
y=data.pop('kmeans')
x=data.drop(columns=['name','artists','id','release_date','song_name'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
model=LGBMClassifier().fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.9992678401283788

# %%
model.score(x_test,y_test)
# Out:
# 0.9947946442003912

# %%
ax = lightgbm.plot_importance(model, max_num_features=10, figsize=(15,15))
plt.show()

# %%
df=cluster.apply(lambda x: x.sort_values(["popularity"],ascending=False))
df.reset_index(level=0, inplace=True)
df
# Out:
#         kmeans  acousticness                                     artists  \
# 87949        0         0.731                    ['Powfu', 'beabadoobee']
# 87941        0         0.233  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']
# 87856        0         0.751                           ['Lewis Capaldi']
# 87857        0         0.902                           ['Billie Eilish']
# 88000        0         0.260                              ['DripReport']
# ...        ...           ...                                         ...
# 128653       1         0.931                              ['Ghantasala']
# 128668       1         0.981                       ['Phiroz J Bhagalia']
# 128671       1         0.928                         ['Lata Mangeshkar']
# 128675       1         0.856                         ['Carlos Di Sarli']
# 0            1         0.995                         ['Carl Woitschach']
#
#         danceability  duration_ms  energy  explicit                      id  \
# 87949          0.726       173333   0.431         0  7eJMfftS33KTjuF7lTsMCx
# 87941          0.716       165978   0.537         1  39Yp9wwQiSRIDOvrVg7mbk
# 87856          0.501       182161   0.405         0  7qEHsqek33rTcFNT9PFqLf
# 87857          0.704       245426   0.225         0  3ZCTVFBt2Brf31RLEnCkWJ
# 88000          0.903       106000   0.327         1  2alc8VZAzDgdAsL2QMk3hu
# ...              ...          ...     ...       ...                     ...
# 128653         0.657       162267   0.728         0  05zpcoyGNTszqowJwUFHET
# 128668         0.671       189533   0.219         0  08DtTHZK3SpnKLjDwdQIZH
# 128671         0.664       201273   0.246         0  08uKhdJN2DClbsp9cxFxgz
# 128675         0.598       147632   0.598         0  099Hl3UCSvbGwuhmCrImoK
# 0              0.708       158648   0.195         0  6KbQ3uYMLKb5jDxLF7wYDD
#
#         instrumentalness  key  ...  loudness  mode  \
# 87949           0.000000    8  ...    -8.765     0
# 87941           0.000000    0  ...    -7.648     0
# 87856           0.000000    1  ...    -5.679     1
# 87857           0.657000    6  ...   -14.454     0
# 88000           0.011000    1  ...    -9.727     1
# ...                  ...  ...  ...       ...   ...
# 128653          0.056500    1  ...    -4.277     1
# 128668          0.001260    5  ...    -8.025     1
# 128671          0.000381    1  ...    -8.820     1
# 128675          0.901000    0  ...    -4.781     0
# 0               0.563000   10  ...   -12.428     1
#
#                                                      name popularity  \
# 87949   death bed (coffee for your head) (feat. beabad...         97
# 87941                                          THE SCOTTS         96
# 87856                                   Someone You Loved         92
# 87857                                 everything i wanted         90
# 88000                                            Skechers         89
# ...                                                   ...        ...
# 128653                                  Manasuloni Manasa          0
# 128668                     Jar Jahangir No Jhagado, Pt. 1          0
# 128671                       Ham Pyar Tumhin Se Karte Hai          0
# 128675                                        El Amanecer          0
# 0                             Singende Bataillone 1. Teil          0
#
#         release_date speechiness    tempo  valence  year  \
# 87949     2020-02-08      0.1350  144.026    0.348  2020
# 87941     2020-04-24      0.0514  129.979    0.280  2020
# 87856     2019-05-17      0.0319  109.891    0.446  2019
# 87857     2019-11-13      0.0994  120.006    0.243  2019
# 88000     2020-01-12      0.0877  100.008    0.274  2020
# ...              ...         ...      ...      ...   ...
# 128653    1952-12-01      0.0730   79.856    0.893  1952
# 128668    1952-10-01      0.5090  148.962    0.789  1952
# 128671    1952-12-01      0.0308  112.840    0.673  1952
# 128675          1952      0.0492  117.533    0.587  1952
# 0               1928      0.0506  118.469    0.779  1928
#
#                                                 song_name
# 87949   death bed (coffee for your head) (feat. beabad...
# 87941                                          THE SCOTTS
# 87856                                   Someone You Loved
# 87857                                 everything i wanted
# 88000                                            Skechers
# ...                                                   ...
# 128653                                  Manasuloni Manasa
# 128668                     Jar Jahangir No Jhagado, Pt. 1
# 128671                       Ham Pyar Tumhin Se Karte Hai
# 128675                                        El Amanecer
# 0                             Singende Bataillone 1. Teil
#
# [132940 rows x 21 columns]

# %%
cluster.apply(lambda x: x.sort_values(["popularity"],ascending=False))
# Out:
#                acousticness                                     artists  \
# kmeans
# 0      87949          0.731                    ['Powfu', 'beabadoobee']
#        87941          0.233  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']
#        87856          0.751                           ['Lewis Capaldi']
#        87857          0.902                           ['Billie Eilish']
#        88000          0.260                              ['DripReport']
# ...                     ...                                         ...
# 1      128653         0.931                              ['Ghantasala']
#        128668         0.981                       ['Phiroz J Bhagalia']
#        128671         0.928                         ['Lata Mangeshkar']
#        128675         0.856                         ['Carlos Di Sarli']
#        0              0.995                         ['Carl Woitschach']
#
#                danceability  duration_ms  energy  explicit  \
# kmeans
# 0      87949          0.726       173333   0.431         0
#        87941          0.716       165978   0.537         1
#        87856          0.501       182161   0.405         0
#        87857          0.704       245426   0.225         0
#        88000          0.903       106000   0.327         1
# ...                     ...          ...     ...       ...
# 1      128653         0.657       162267   0.728         0
#        128668         0.671       189533   0.219         0
#        128671         0.664       201273   0.246         0
#        128675         0.598       147632   0.598         0
#        0              0.708       158648   0.195         0
#
#                                    id  instrumentalness  key  liveness  \
# kmeans
# 0      87949   7eJMfftS33KTjuF7lTsMCx          0.000000    8     0.696
#        87941   39Yp9wwQiSRIDOvrVg7mbk          0.000000    0     0.157
#        87856   7qEHsqek33rTcFNT9PFqLf          0.000000    1     0.105
#        87857   3ZCTVFBt2Brf31RLEnCkWJ          0.657000    6     0.106
#        88000   2alc8VZAzDgdAsL2QMk3hu          0.011000    1     0.108
# ...                               ...               ...  ...       ...
# 1      128653  05zpcoyGNTszqowJwUFHET          0.056500    1     0.416
#        128668  08DtTHZK3SpnKLjDwdQIZH          0.001260    5     0.111
#        128671  08uKhdJN2DClbsp9cxFxgz          0.000381    1     0.108
#        128675  099Hl3UCSvbGwuhmCrImoK          0.901000    0     0.628
#        0       6KbQ3uYMLKb5jDxLF7wYDD          0.563000   10     0.151
#
#                loudness  mode  \
# kmeans
# 0      87949     -8.765     0
#        87941     -7.648     0
#        87856     -5.679     1
#        87857    -14.454     0
#        88000     -9.727     1
# ...                 ...   ...
# 1      128653    -4.277     1
#        128668    -8.025     1
#        128671    -8.820     1
#        128675    -4.781     0
#        0        -12.428     1
#
#                                                             name  popularity  \
# kmeans
# 0      87949   death bed (coffee for your head) (feat. beabad...          97
#        87941                                          THE SCOTTS          96
#        87856                                   Someone You Loved          92
#        87857                                 everything i wanted          90
#        88000                                            Skechers          89
# ...                                                          ...         ...
# 1      128653                                  Manasuloni Manasa           0
#        128668                     Jar Jahangir No Jhagado, Pt. 1           0
#        128671                       Ham Pyar Tumhin Se Karte Hai           0
#        128675                                        El Amanecer           0
#        0                             Singende Bataillone 1. Teil           0
#
#               release_date  speechiness    tempo  valence  year  \
# kmeans
# 0      87949    2020-02-08       0.1350  144.026    0.348  2020
#        87941    2020-04-24       0.0514  129.979    0.280  2020
#        87856    2019-05-17       0.0319  109.891    0.446  2019
#        87857    2019-11-13       0.0994  120.006    0.243  2019
#        88000    2020-01-12       0.0877  100.008    0.274  2020
# ...                    ...          ...      ...      ...   ...
# 1      128653   1952-12-01       0.0730   79.856    0.893  1952
#        128668   1952-10-01       0.5090  148.962    0.789  1952
#        128671   1952-12-01       0.0308  112.840    0.673  1952
#        128675         1952       0.0492  117.533    0.587  1952
#        0              1928       0.0506  118.469    0.779  1928
#
#                                                        song_name
# kmeans
# 0      87949   death bed (coffee for your head) (feat. beabad...
#        87941                                          THE SCOTTS
#        87856                                   Someone You Loved
#        87857                                 everything i wanted
#        88000                                            Skechers
# ...                                                          ...
# 1      128653                                  Manasuloni Manasa
#        128668                     Jar Jahangir No Jhagado, Pt. 1
#        128671                       Ham Pyar Tumhin Se Karte Hai
#        128675                                        El Amanecer
#        0                             Singende Bataillone 1. Teil
#
# [132940 rows x 20 columns]

# %%
detection_model_path = 'haarcascade_files\haarcascade_frontalface_default.xml'
emotion_model_path = 'final_model.h5'
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ["happy","sad"]

# %%
# from keras.utils import img_to_array
def emotion_testing():
        cap=cv2.VideoCapture(0)
        while True:
            ret,test_img=cap.read()# captures frame and returns boolean value and captured image
            if not ret:
                continue
            gray_img= cv2.cvtColor(test_img, cv2.COLOR_BGR2GRAY)

            faces_detected = face_detection.detectMultiScale(gray_img, 1.32, 5)


            for (x,y,w,h) in faces_detected:
                cv2.rectangle(test_img,(x,y),(x+w,y+h),(255,0,0),thickness=7)
                roi_gray=gray_img[y:y+w,x:x+h]#cropping region of interest i.e. face area from  image
                roi_gray=cv2.resize(roi_gray,(48,48))
                img_pixels = img_to_array(roi_gray)
                img_pixels = np.expand_dims(img_pixels, axis = 0)
                img_pixels /= 255

                predictions = emotion_classifier.predict(img_pixels)

                #find max indexed array
                max_index = np.argmax(predictions[0])
                predicted_emotion = EMOTIONS[max_index]

                cv2.putText(test_img, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

            resized_img = cv2.resize(test_img, (1000, 700))
            cv2.imshow('Facial emotion analysis ',resized_img)



            if cv2.waitKey(0) & 0xFF == ord('q'):
                     break
        cap.release()
        cv2.destroyAllWindows
        return predicted_emotion

# %%
emotion_word=emotion_testing()
if emotion_word=='sad':
    emotion_code=0
else:
    emotion_code=1
# Out:
# 1/1 [==============================] - 0s 482ms/step

# %%
def get_results(emotion_code):
  NUM_RECOMMEND=10
  happy_set=[]
  sad_set=[]
  if emotion_code==0:
      happy_set.append(df[df['kmeans']==0]['song_name'].head(NUM_RECOMMEND))
      return pd.DataFrame(happy_set).T
  else:
      sad_set.append(df[df['kmeans']==1]['song_name'].head(NUM_RECOMMEND))
      return pd.DataFrame(sad_set).T

# %%
print(get_results(emotion_code))
if emotion_word=='sad':
    print('emotion detected is SAD')
else:
    print('emotion detected is HAPPY')
# Out:
#                                   song_name
# 87852  ily (i love you baby) (feat. Emilee)
# 87844                            Supalonely
# 87858                          Dance Monkey
# 87952       Rain On Me (with Ariana Grande)
# 87953     Stuck with U (with Justin Bieber)
# 87951                                 GOOBA
# 87850                       Don't Start Now
# 87969                            Boss Bitch
# 87945                       Blueberry Faygo
# 87944                          WHATS POPPIN
# emotion detected is HAPPY
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
